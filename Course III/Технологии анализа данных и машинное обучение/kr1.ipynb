# %%
import random
import sys
from time import time


def weighted_choice(items):
    """
    Выбирает случайный элемент из набора значений, где набор значений - это список кортежей в
    форме (шт., вес). Вес определяет вероятность выбора своего
    соответствующего пункта.
    """

    weight_total = sum((item[1] for item in items))
    n = random.uniform(0, weight_total)
    last_item = None
    for item, weight in items:
        if n < weight:
            return item
        n = n - weight
        last_item = item
    return last_item


def random_char():
    return random.choice("АаБбВвГгДдЕеЁёЖжЗзИиЙйКкЛлМм.НнОоПпРрСсТтУуФфХхЦцЧчШшЩщЪъЫыЬьЭэЮюЯя ")


def random_population():
    """
      Возвращает список POP_SIZE, каждый из которых генерируется случайным образом путем итерации
    DNA_SIZE раз, чтобы сгенерировать строку случайных символов с помощью random_char ().
    """

    pop = []
    for i in range(POP_SIZE):
        dna = ""
        for c in range(DNA_SIZE):
            dna += random_char()
        pop.append(dna)
    return pop


def fitness(dna):
    """
      Для каждого гена в ДНК эта функция вычисляет разницу между
    ним и символом в той же позиции в ОПТИМАЛЬНОЙ строке. Значения разницы
    суммируются, а затем возвращаются.
    """

    a = 0
    for c in range(DNA_SIZE):
        a += abs(ord(dna[c]) - ord(OPTIMAL[c]))
    return a


def mutation(dna):
    """
      Для каждого гена в ДНК есть шанс 1 / mutation_chance, что он будет
    замещен  случайным символом. Это обеспечивает разнообразие в
    популяции, и гарантирует, что будет трудно застрять в локальных минимумах.
    """

    dna_out = ""
    mutation_chance = 100
    for c in range(DNA_SIZE):
        if int(random.random() * mutation_chance) == 1:
            dna_out += random_char()
        else:
            dna_out += dna[c]
    return dna_out


def crossover(dna1, dna2):
    """
    Crossover 2 dna используя рандомный индекс.
    Сохраняют свою первую часть до кроссовера.
    Но их концы меняются местами.
    """

    pos = int(random.random() * DNA_SIZE)
    return dna1[:pos] + dna2[pos:], dna2[:pos] + dna1[pos:]


# Необходимые переменные
# Вводим искомую строчку (фразу)
# Устанавливаем количество поколений

OPTIMAL = "Первый искусственный интеллект"
DNA_SIZE = len(OPTIMAL)
POP_SIZE = 400
GENERATIONS = 9999999999

# Будем замерять время вычисления алгоритма
start = time()

# Создает начальную популяцию.
# Это создаст список строк POP_SIZE, каждая из которых инициализирована последовательностью случайных символов.
population = random_population()
fittest_string = None

# Моделируем заданное нами количество поколений
generation = 0
while generation <= GENERATIONS:
    generation += 1
    print(f"Generation №{generation}\n Random sample:{population[0]} ")
    weighted_population = []
    for individual in population:
        fitness_val = fitness(individual)

        # Генерирует пару (individual,fitness),
        # учитывая, чтобы мы случайно не поделили на ноль.
        if fitness_val == 0:
            pair = (individual, 1.0)
        else:
            pair = (individual, 1.0 / fitness_val)

        weighted_population.append(pair)

    population = []

    # Выбирает двух случайных особей на основе их вероятностей пригодности,
    # скрещивает их гены в случайной точке,
    # изменяет их и снова добавляет в популяцию для следующей итерации.
    for _ in range(int(POP_SIZE / 2)):
        # Селекция
        ind1 = weighted_choice(weighted_population)
        ind2 = weighted_choice(weighted_population)

        # Переплетение
        ind1, ind2 = crossover(ind1, ind2)

        #  Мутация и возврат обратно в популяцию
        population.append(mutation(ind1))
        population.append(mutation(ind2))

    # Отображает строку с наивысшим рейтингом после итерации всех поколений.
    # Это будет ближайшая строка к ОПТИМАЛЬНОЙ строке,
    # то есть она будет иметь наименьшее значение пригодности.

    fittest_string = population[0]
    minimum_fitness = fitness(population[0])

    for individual in population:
        ind_fitness = fitness(individual)
        if ind_fitness <= minimum_fitness:
            fittest_string = individual
            minimum_fitness = ind_fitness

    # Обрывает цикл, если мы нашли подходящую  строчку
    if fittest_string == OPTIMAL:
        break

end = time()
print(f"\nTime:{round(end - start, 1)}s.\n")
print(f"Final string: {fittest_string}")
# Out:
# Generation №1
#  Random sample:эЗкбсщАБчвъФёечш.ФЕлСЧЧйюККеДр
# Generation №2
#  Random sample:чНЮЁкшЖВУТЛФрвЗЙтЖЗкъиЭзГДВПЙп
# Generation №3
#  Random sample:чНЮЁкш щмъфЩлъЭУхрЙГКЛЫЗчёюядУ
# Generation №4
#  Random sample:арпФкехлМЗАЫАЫ.кпИНЫхРгбрЙчЮюё
# Generation №5
#  Random sample:ппЭЗвхяБИицйэыПмВмфгнЁСюТОЗВЭИ
# Generation №6
#  Random sample:шИэтаьСпДюЙБъОхсУЫоиДОЁПВеГЕлз
# Generation №7
#  Random sample:чРШиНбШяКИФгШГШЪТЯПЕлТМнСъеГсХ
# Generation №8
#  Random sample:МыОчЦЧЖяФЗя юРбЭъВКЧЦщЛюХкбКис
# Generation №9
#  Random sample:кНШиНбШЩОЩцйЦыйидЛуЫ ГиОЗИСЗЁЩ
# Generation №10
#  Random sample:жЙвЩФОЁзЮТРгКщцИьЛуЫ ГЕЯцУжеЮЫ
# Generation №11
#  Random sample:ЫТпФФО.ГгглеХУЛюЙАтрЮтРЙОХомфб
# Generation №12
#  Random sample:ФзфЁкО.вёЬьИщЩДОцьЛю.ДмЗЦВаЬСР
# Generation №13
#  Random sample:ФзфНкиЁзкхбИщЩДОцАтрЮтРЙОХомфб
# Generation №14
#  Random sample:ФзфЁкО.мМхбНОурГЩьтв ёЕЯцУжеЭи
# Generation №15
#  Random sample:ЖдщЩФО.ГуЫХсЯпШёчьЛю.ДлФтеЗыВА
# Generation №16
#  Random sample:ФёпФФО.мМхаИщуЦЬрЁьы ТмЯючасДш
# Generation №17
#  Random sample:жэЮХФО.мДюЙБРцкЬъеуЫ ёоюцУЗыВА
# Generation №18
#  Random sample:еЕЯцсч.ГыайЗУЬучкПЛю.БЕЯщлШЙСЯ
# Generation №19
#  Random sample:арщчвО.ГмбХЭЯпШёчьЛю.умВМыУПэщ
# Generation №20
#  Random sample:ЦУыЩшО.мМгбиОуДЬЩьЛо.ДмВбгУчэл
# Generation №21
#  Random sample:жЙвлМО.мХхбиыуЧЬььЛю.мЕрВйощцр
# Generation №22
#  Random sample:ЫХЮткО.ГМхХЪСЬуъДЩью.ДмНАшпыжи
# Generation №23
#  Random sample:ПБлЩФО.мЮСфЪчЬбчДЩью.ДмлАчаожщ
# Generation №24
#  Random sample:УдовэУ ймйфссугЬкльг Эмщелкейу
# Generation №122
#  Random sample:Удрвэе ймйфссуяЁкмьЬ тмсЬлкейъ
# Generation №123
#  Random sample:УдмЩэж ммкфссудйоььг ЭмтЬлкейъ
# Generation №124
#  Random sample:Мммвэж ммУфссуйжкмьь имтелкейу
# Generation №125
#  Random sample:Уьмвэв ммкфссуежкмьйгммсешкЙйу
# Generation №126
#  Random sample:УдмЩжж ммйфссугжкмьй днсешкейу
# Generation №127
#  Random sample:Уиодэм ммкфсцуежкмьг имтТлкейу
# Generation №128
#  Random sample:УдмвэЕ ммкфссуежкмьй имтенкейу
# Generation №129
#  Random sample:Удовэж ммкфссугжлмщг имсесдцйу
# Generation №130
#  Random sample:Удомэж куквссуЭэкмьй имсескейр
# Generation №131
#  Random sample:Удовэж лфкфссугжкльй ммселжейк
# Generation №132
#  Random sample:Ндмвэж ймуфссугжкльф ммсЬлкейу
# Generation №133
#  Random sample:Тдмвэе лфкхстуеЮлмьй имсенкеру
# Generation №134
#  Random sample:Уговэж лфкфссугжкльй имсеукейъ
# Generation №135
#  Random sample:Уговэж лфкфссугжкльй ммселлпйу
# Generation №136
#  Random sample:Удрвэж ймйфссуежкмьй имтелкейу
# Generation №137
#  Random sample:Чдмвэж ймзфссугжкльй имтенкену
# Generation №138
#  Random sample:Мдмнэе лфзфссугжкмьй имсенкейу
# Generation №139
#  Random sample:Чдмвэж ммкфссугжкмый имтенкейу
# Generation №140
#  Random sample:Удрдэж лмкфссугжкмУй имтескейу
# Generation №141
#  Random sample:МдоЭэж йукХссугжкмьй имсенкейу
# Generation №142
#  Random sample:Удмвэв ммйфпсуЮжкмый имтенкейо
# Generation №143
#  Random sample:Уднвэж ймйфФсугжкмьй имтелкейу
# Generation №144
#  Random sample:Мговэж ймйфссуежкмьй имтелкейу
# Generation №145
#  Random sample:Уднвэж мфйфссугжкмьй имселЮейу
# Generation №146
#  Random sample:Удмвэжулфкфссугжкмьй имтелкейу
# Generation №147
#  Random sample:Уддвэж лфйфссугжкмьй имтелкейу
# Generation №148
#  Random sample:Удрвэж лфкфссугжкмьй ерселкезу
# Generation №149
#  Random sample:Удовэж кмшфссугжкмьй емтелкейу
# Generation №150
#  Random sample:Удрвэж ммкфсБужжкмьй пмтднМейъ
# Generation №151
#  Random sample:Удрвэж ймкфссугжкмьй имселкейу
# Generation №152
#  Random sample:одрвэж мукфссугжщмьй иытелкейо
# Generation №153
#  Random sample:Уднвэж кукфссугжкмьЫ рмткскейу
# Generation №154
#  Random sample:Удрвэж мукфхсуажомьй имтенкейу
# Generation №155
#  Random sample:Удрвэж ммкфссугжлмый имуелкейу
# Generation №156
#  Random sample:Уднвэж мукхссугжлмый имтелкейу
# Generation №157
#  Random sample:Удрвэж муйфчсугжкльй имселЕейу
# Generation №158
#  Random sample:Иеувэж мфйхссугжкмый имтеЦкейо
# Generation №159
#  Random sample:Удрдэж мукфссуежкльй имселкейу
# Generation №160
#  Random sample:Мдрдэж мукфссужжкмьй имтенкейй
