# %% [markdown]
# 1)Напишите проверку законов де Моргана

# %% [markdown]
# ![%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png](attachment:%D0%B8%D0%B7%D0%BE%D0%B1%D1%80%D0%B0%D0%B6%D0%B5%D0%BD%D0%B8%D0%B5.png)

# %% [markdown]
# 2)Пользователь делает ввод с клавиатуры. Если он вводит "True", то должен печататься ответ "ИСТИНА", если "False", то печатается "ЛОЖЬ", если ничего не пишет, то "Введите какое-либо значение", если отличное от True или False, то выводится на печать "Введенные данные не поддерживаются"

# %% [markdown]
# 3)  Записать систему неравенств в одну строку БЕЗ использования and, or, True, False (разрешаются только операции сравнения):
# * x^2 - 6 > - x
# * x > 0
#
# Проверить на x = -5 (False), 3 (True), 1 (False), 0 (False):
#
# Вывести результат в виде: "x = -5: False"

# %% [markdown]
# 4) Записать все следующие условия в одну цепочку неравенств (без использования логических операторов):
#
#     0 <= a <= c
#     0 <= b < c
#     b == 2
#     0 <= c < 5

# %% [markdown]
# 5) Запросить пользователя ввести две строки. Проверить, что первая строка длиннее второй, но при этом находится ближе в лексикографическом порядке. Подобрать пару строк, удовлетворяющую условию.

# %% [markdown]
# 6) Если в произвольной входной строке встречается "!!!", выводить на печать "exclaim". При этом если строка начинается с "!!!", вместо этого выводить "Nota bene: " и исходную строку без восклицательных знаков. Если встречается "???", то выводить "question". Если встречаются оба ("!!!" и "???"), то ничего не выводить. В других случаях выводить "random".

# %% [markdown]
# 7) Протестировать инструкцию: x = a _if_ condition else b на примере: в переменную friend записать x, если в x встречается слово "banana", в ином случае записать в нее y.
#
# Пример: при x = "banana monkey", y = "orangutan" значение переменной friend должно быть равно "banana monkey".

# %% [markdown]
# 8) Вводятся три разных числа. Найти, какое из них является средним (больше одного, но меньше другого).

# %% [markdown]
# 9) Найти корни квадратного уравнения и вывести их на экран, если они есть. Если корней нет, то вывести сообщение об этом. Конкретное квадратное уравнение определяется коэффициентами a, b, c, которые вводит пользователь.

# %% [markdown]
# 10) Вводятся три целых числа. Определить какое из них наибольшее.

# %% [markdown]
# 11) По длинам трех отрезков, введенных пользователем, определить возможность существования треугольника, составленного из этих отрезков. Если такой треугольник существует, то определить, является ли он разносторонним, равнобедренным или равносторонним.

# %% [markdown]
# 12) Определить четверть координатной плоскости, которой принадлежит точка. Координаты точки ввести с клавиатуры.

# %% [markdown]
# 13) Написать программу, которая переводит градусаы Цельсия в градусы по Фаренгейту и наоборот
#
# c/5 = f-32/9, где c - градусы Цельсия, а f - градусы по Фаренгейту.
#
# Пример:
#
# Ввод: 15 C
#
# Вывод: 15 C - 6.55 F

# %% [markdown]
# 14) Проверить является ли введенное слово Палиндромом
